# %%
# 1. Write your custom function here!

# For this demo, we do a basic NDVI calculation, inputting and returning a pandas DataFrame.
# Note that the function must input and return a pandas DataFrame. This is a requirement.
def compute_ndvi(df):
    # Perform your calculations
    df['ndvi'] = (df['SR_B5'] - df['SR_B4']) / (df['SR_B5'] + df['SR_B4'])
    return df[['X', 'Y', 'ndvi']]

def compute_ndvi(df):
    # Perform your calculations
    df['ndvi'] = (df['band_2'] - df['band_1']) / (df['band_2'] + df['band_1'])
    return df[['X', 'Y', 'ndvi']]

# %%
raster_path = r"R:\SCRATCH\adrianom\landsat_us_test\earthengine-lcs-data\mosaic.tif"

# %%
# 5. Preview the dataset and the results before doing a full run!
# This allows users to inspect the structure and content of the data to ensure it behaves as expected prior to running a full computation.
# 6. Do the full computation here!
# Click on the link to the Dask dashboard to view the computation in real time!
from robustraster import run
import pandas as pd

df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
df_list = ["X", "Y", "ndvi"]

chunks = {"time": 48, "X": 2048, "Y": 1024}
run(
    dataset=raster_path,
    source="local",
    dataset_kwargs={
    #'geometry': Plumas_Boundaries,
    'crs': 'EPSG:3310',
    'scale': 30,
    'output_template': df_list,
    'chunks': chunks
    },
    user_function_params={
        "user_function": compute_ndvi,
        "user_function_args": (),
        "user_function_kwargs": {},
        "chunks": chunks,
        "output_template": df_list,
        "max_iterations": None
    },
    preview_dataset=True

)
# Out:
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\google\cloud\storage\_http.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# <xarray.Dataset> Size: 2kB
# Dimensions:      (time: 1, Y: 10, X: 10)
# Coordinates:
#   * time         (time) int32 4B 0
#   * X            (X) float64 80B -2.356e+06 -2.356e+06 ... -2.356e+06 -2.356e+06
#   * Y            (Y) float64 80B 3.166e+06 3.166e+06 ... 3.165e+06 3.165e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     band_1       (time, Y, X) float64 800B dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     band_2       (time, Y, X) float64 800B dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
# band_1 dims: ('time', 'Y', 'X') shape: (1, 10, 10) ndim(lazy): 3 chunks: ((1,), (10,), (10,))
# band_2 dims: ('time', 'Y', 'X') shape: (1, 10, 10) ndim(lazy): 3 chunks: ((1,), (10,), (10,))
# band_1 first-block-shape: (1, 10, 10)
# band_2 first-block-shape: (1, 10, 10)
#
# Dataset preview:
#    time          Y          X  band_1  band_2  spatial_ref
# 0     0  3165735.0 -2356125.0     NaN     NaN            0
# 1     0  3165735.0 -2356095.0     NaN     NaN            0
# 2     0  3165735.0 -2356065.0     NaN     NaN            0
# 3     0  3165735.0 -2356035.0     NaN     NaN            0
# 4     0  3165735.0 -2356005.0     NaN     NaN            0
#
# User function output preview:
#            X          Y  ndvi
# 0 -2356125.0  3165735.0   NaN
# 1 -2356095.0  3165735.0   NaN
# 2 -2356065.0  3165735.0   NaN
# 3 -2356035.0  3165735.0   NaN
# 4 -2356005.0  3165735.0   NaN

# %%
# 6. Do the full computation here!
# Click on the link to the Dask dashboard to view the computation in real time!
from robustraster import run
import pandas as pd

df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
df_list = ["X", "Y", "ndvi"]

chunks = {"time": 48, "X": 2048, "Y": 1024}
run(
    dataset=raster_path,
    source="local",
    dataset_kwargs={
    #'geometry': Plumas_Boundaries,
    'crs': 'EPSG:3310',
    'scale': 30,
    'output_template': df_list,
    'chunks': chunks
},
    user_function_params={
        "user_function": compute_ndvi,
        "user_function_args": (),
        "user_function_kwargs": {},
        "chunks": chunks,
        "output_template": df_list,
        "max_iterations": None
    },
    export_kwargs={
        "mode": "raster",
        "file_format": "GTiff",
        "output_folder": "tiles33",
        "vrt": True,
        "report": True}, 
        #"export_to_gcs": True,
        #"gcs_credentials": r"R:\SCRATCH\adrianom\credentials\cloud_storage\robust-raster-b9a2bc301bc9.json",
        #"gcs_bucket": "raster-bucket-test25678"},
    dask_mode="custom",
    dask_kwargs={
        "n_workers": 8,
        "threads_per_worker": 1,
        "memory_limit": "20GB"
    }
)
# Out:
# Dask dashboard is available at: http://127.0.0.1:8787/status
# [robustraster] Dask cluster started: <Client: 'tcp://127.0.0.1:53205' processes=8 threads=8, memory=149.01 GiB>
# <xarray.Dataset> Size: 238GB
# Dimensions:      (time: 1, Y: 96570, X: 153810)
# Coordinates:
#   * time         (time) datetime64[s] 8B 1970-01-01T00:00:01
#   * X            (X) float64 1MB -2.356e+06 -2.356e+06 ... 2.258e+06 2.258e+06
#   * Y            (Y) float64 773kB 3.166e+06 3.166e+06 ... 2.687e+05 2.687e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     band_1       (time, Y, X) float64 119GB dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     band_2       (time, Y, X) float64 119GB dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
# [robustraster] Running user function...
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\distributed\client.py:3362: UserWarning: Sending large graph of size 12.92 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# [robustraster] ❌ ERROR during run(): "None of ['time'] are in the columns"
# [robustraster] Dask client closed.
# [robustraster] Dask cluster shut down.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\12\ipykernel_47880\3685349285.py in ?()
#       6 df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
#       7 df_list = ["X", "Y", "ndvi"]
#       8
#       9 chunks = {"time": 48, "X": 2048, "Y": 1024}
# ---> 10 run(
#      11     dataset=raster_path,
#      12     source="local",
#      13     dataset_kwargs={
#
# r:\scratch\adrianom\code\big-raster-helper\src\robustraster\run_manager.py in ?(dataset, source, dataset_kwargs, user_function_params, user_function, user_function_args, user_function_kwargs, preview_dataset, tune_function, max_iterations, export_kwargs, dask_mode, dask_kwargs, hooks, dask_use_docker, dask_docker_image, dask_docker_kwargs)
#     168                 try:
#     169                     cluster_manager.shutdown()
#     170                 except Exception:
#     171                     pass
# --> 172             print("[robustraster] Dask cluster shut down.")
#
# r:\scratch\adrianom\code\big-raster-helper\src\robustraster\raster_export_manager.py in ?(self, data_source)
#     218                                    template=template_xarray)
#     219
#     220         if self.kwargs.get("report") is True:
#     221             with performance_report(filename="dask_report.html"):
# --> 222                 result.compute()
#     223         else:
#     224             result.compute()
#     225
#
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\core\dataset.py in ?(self, **kwargs)
#     711         --------
#     712         dask.compute
#     713         """
#     714         new = self.copy(deep=False)
# --> 715         return new.load(**kwargs)
#
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\core\dataset.py in ?(self, **kwargs)
#     538         if lazy_data:
#     539             chunkmanager = get_chunked_array_type(*lazy_data.values())
#     540
#     541             # evaluate all the chunked arrays simultaneously
# --> 542             evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     543                 *lazy_data.values(), **kwargs
#     544             )
#     545
#
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\namedarray\daskmanager.py in ?(self, *data, **kwargs)
#      81         self, *data: Any, **kwargs: Any
#      82     ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83         from dask.array import compute
#      84
# ---> 85         return compute(*data, **kwargs)  # type: ignore[no-untyped-call, no-any-return]
#
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\dask\base.py in ?(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658         keys.append(x.__dask_keys__())
#     659         postcomputes.append(x.__dask_postcompute__())
#     660
#     661     with shorten_traceback():
# --> 662         results = schedule(dsk, keys, **kwargs)
#     663
#     664     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\core\parallel.py in ?()
# --> 351     def _wrapper(
#     352         func: Callable,
#     353         args: list,
#     354         kwargs: dict,
#
# r:\scratch\adrianom\code\big-raster-helper\src\robustraster\raster_export_manager.py in ?()
# --> 112     def _user_function_export_wrapper(self, ds, *args):
#     113         """
#     114         Wrapper function that applies either `tune_user_function` or `apply_user_function`.
#     115         to the user's dataset. This will convert the user's dataset to a pandas DataFrame
#
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\pandas\core\frame.py in ?()
# -> 6129     def set_index(
#    6130         self,
#    6131         keys,
#    6132         *,
#
# KeyError: "None of ['time'] are in the columns"
