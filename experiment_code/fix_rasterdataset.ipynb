# %%
# 1. Write your custom function here!

# For this demo, we do a basic NDVI calculation, inputting and returning a pandas DataFrame.
# Note that the function must input and return a pandas DataFrame. This is a requirement.
def compute_ndvi(df):
    # Perform your calculations
    df['ndvi'] = (df['SR_B5'] - df['SR_B4']) / (df['SR_B5'] + df['SR_B4'])
    return df[['X', 'Y', 'ndvi']]

def compute_ndvi(df):
    # Perform your calculations
    df['ndvi'] = (df['band_2'] - df['band_1']) / (df['band_2'] + df['band_1'])
    return df[['time', 'X', 'Y', 'ndvi']]

# %%
raster_path = r"R:\SCRATCH\adrianom\landsat_us_test\earthengine-lcs-data\mosaic.tif"

# %%
# 5. Preview the dataset and the results before doing a full run!
# This allows users to inspect the structure and content of the data to ensure it behaves as expected prior to running a full computation.
# 6. Do the full computation here!
# Click on the link to the Dask dashboard to view the computation in real time!
from robustraster import run
import pandas as pd

df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
df_list = ["X", "Y", "ndvi"]

chunks = {"time": 48, "X": 2048, "Y": 1024}
run(
    dataset=raster_path,
    source="local",
    dataset_kwargs={
    #'geometry': Plumas_Boundaries,
    'crs': 'EPSG:3310',
    'scale': 30,
    'output_template': df_list,
    'chunks': chunks
    },
    user_function_params={
        "user_function": compute_ndvi,
        "user_function_args": (),
        "user_function_kwargs": {},
        "chunks": chunks,
        "output_template": df_list,
        "max_iterations": None
    },
    preview_dataset=True

)

# %%
# 6. Do the full computation here!
# Click on the link to the Dask dashboard to view the computation in real time!
from robustraster import run
import pandas as pd

df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
df_list = ["x", "y", "ndvi"]

chunks = {"time": 48, "X": 4096, "Y": 4096}
run(
    dataset=raster_path,
    source="local",
    dataset_kwargs={
    #'geometry': Plumas_Boundaries,
    'crs': 'EPSG:3310',
    'scale': 30,
    'output_template': df_list,
    'chunks': chunks
},
    user_function_params={
        "user_function": compute_ndvi,
        "user_function_args": (),
        "user_function_kwargs": {},
        "chunks": chunks,
        "output_template": df_list,
        "max_iterations": None
    },
    export_kwargs={
        "mode": "raster",
        "file_format": "GTiff",
        "output_folder": "tiles33",
        "vrt": True,
        "report": True}, 
        #"export_to_gcs": True,
        #"gcs_credentials": r"R:\SCRATCH\adrianom\credentials\cloud_storage\robust-raster-b9a2bc301bc9.json",
        #"gcs_bucket": "raster-bucket-test25678"},
    dask_mode="custom",
    dask_kwargs={
        "n_workers": 8,
        "threads_per_worker": 1,
        "memory_limit": "30GB"
    }
)
# Out:
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\google\cloud\storage\_http.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Dask dashboard is available at: http://127.0.0.1:8787/status
# [robustraster] Dask cluster started: <Client: 'tcp://127.0.0.1:58796' processes=8 threads=8, memory=223.52 GiB>
# DATA READ
#
# <xarray.Dataset> Size: 238GB
# Dimensions:      (time: 1, Y: 96570, X: 153810)
# Coordinates:
#   * time         (time) int32 4B 0
#   * X            (X) float64 1MB -2.356e+06 -2.356e+06 ... 2.258e+06 2.258e+06
#   * Y            (Y) float64 773kB 3.166e+06 3.166e+06 ... 2.687e+05 2.687e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     band_1       (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
#     band_2       (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
# Attributes:
#     crs:      EPSG:5070
# [robustraster] Running user function...
# TEMPLATE!!!
#
# <xarray.Dataset> Size: 356GB
# Dimensions:      (time: 1, Y: 96570, X: 153810)
# Coordinates:
#   * time         (time) int32 4B 0
#   * X            (X) float64 1MB -2.356e+06 -2.356e+06 ... 2.258e+06 2.258e+06
#   * Y            (Y) float64 773kB 3.166e+06 3.166e+06 ... 2.687e+05 2.687e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     x            (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
#     y            (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
#     ndvi         (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
# Attributes:
#     crs:      EPSG:5070
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, y: 4096, x: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * y            (y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * x            (x) float64 33kB 1.576e+06 1.576e+06 ... 1.699e+06 1.699e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, y, x) float64 134MB 0.7882 0.8294 ... 0.6007 0.4639
# PETER GABRIEL
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, y: 4096, x: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * y            (y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * x            (x) float64 33kB -1.619e+06 -1.619e+06 ... -1.496e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, y, x) float64 134MB 0.1617 0.2018 ... 0.1876 0.1629
# PETER GABRIEL
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, y: 4096, x: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * y            (y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * x            (x) float64 33kB 1.33e+06 1.33e+06 ... 1.453e+06 1.453e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, y, x) float64 134MB 0.8639 0.8479 ... 0.8065 0.8516
# PETER GABRIEL
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, y: 4096, x: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * y            (y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * x            (x) float64 33kB -1.987e+06 -1.987e+06 ... -1.865e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, y, x) float64 134MB 0.1193 0.1227 ... 0.1131 0.0945
# PETER GABRIEL
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, y: 4096, x: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * y            (y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * x            (x) float64 33kB 1.822e+06 1.822e+06 ... 1.945e+06 1.945e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, y, x) float64 134MB 0.7594 0.7517 0.743 ... 1.391 0.3432
# PETER GABRIEL
# Exported: tiles33\chunk_8068642743066424044_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-7299679404589951070_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_6968900575900143644_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_2451422129735323121_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-2232329874841990347_time_0.tif with bands ['ndvi']
# [robustraster] ❌ ERROR during run(): Dimensions {'X', 'Y'} missing on returned object.
# 2025-12-01 16:54:05,488 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,489 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,490 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,491 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,491 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,517 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,518 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:05,519 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-12-01 16:54:06,500 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOMainLoop object at 0x000001D4C6313F10>>, <Task finished name='Task-22866' coro=<SpecCluster._correct_state_internal() done, defined at r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\distributed\deploy\spec.py:346> exception=TimeoutError()>)
# Traceback (most recent call last):
#   File "r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\asyncio\tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\tornado\ioloop.py", line 782, in _discard_future_result
#     future.result()
# asyncio.exceptions.TimeoutError
# [robustraster] Dask client closed.
# [robustraster] Dask cluster shut down.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 10
#       7 df_list = ["x", "y", "ndvi"]
#       9 chunks = {"time": 48, "X": 4096, "Y": 4096}
# ---> 10 run(
#      11     dataset=raster_path,
#      12     source="local",
#      13     dataset_kwargs={
#      14     #'geometry': Plumas_Boundaries,
#      15     'crs': 'EPSG:3310',
#      16     'scale': 30,
#      17     'output_template': df_list,
#      18     'chunks': chunks
#      19 },
#      20     user_function_params={
#      21         "user_function": compute_ndvi,
#      22         "user_function_args": (),
#      23         "user_function_kwargs": {},
#      24         "chunks": chunks,
#      25         "output_template": df_list,
#      26         "max_iterations": None
#      27     },
#      28     export_kwargs={
#      29         "mode": "raster",
#      30         "file_format": "GTiff",
#      31         "output_folder": "tiles33",
#      32         "vrt": True,
#      33         "report": True},
#      34         #"export_to_gcs": True,
#      35         #"gcs_credentials": r"R:\SCRATCH\adrianom\credentials\cloud_storage\robust-raster-b9a2bc301bc9.json",
#      36         #"gcs_bucket": "raster-bucket-test25678"},
#      37     dask_mode="custom",
#      38     dask_kwargs={
#      39         "n_workers": 8,
#      40         "threads_per_worker": 1,
#      41         "memory_limit": "30GB"
#      42     }
#      43 )
#
# File r:\scratch\adrianom\code\big-raster-helper\src\robustraster\run_manager.py:139, in run(dataset, source, dataset_kwargs, user_function_params, preview_dataset, tune_function, export_kwargs, dask_mode, dask_kwargs, hooks, dask_use_docker, dask_docker_image, dask_docker_kwargs)
#     134     processor = VectorExportProcessor(
#     135         user_function_handler=handler,
#     136         **export_kwargs
#     137     )
#     138 print("[robustraster] Running user function...")
# --> 139 processor.run_and_export_results(data_source)
#     141 client.close()
#     142 client.shutdown()
#
# File r:\scratch\adrianom\code\big-raster-helper\src\robustraster\raster_export_manager.py:291, in RasterExportProcessor.run_and_export_results(self, data_source)
#     284     #print(ds_tile)
#     285     result_tile = xr.map_blocks(
#     286         self._user_function_export_wrapper,
#     287         ds_tile,
#     288         template=template_tile,
#     289     )
# --> 291     result_tile.compute()
#     293 if self.kwargs.get("vrt"):
#     294     self.export_vrt(data_source)
#
# File r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\core\dataset.py:715, in Dataset.compute(self, **kwargs)
#     691 """Manually trigger loading and/or computation of this dataset's data
#     692 from disk or a remote source into memory and return a new dataset.
#     693 Unlike load, the original dataset is left unaltered.
#    (...)
#     712 dask.compute
#     713 """
#     714 new = self.copy(deep=False)
# --> 715 return new.load(**kwargs)
#
# File r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\core\dataset.py:542, in Dataset.load(self, **kwargs)
#     539 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     541 # evaluate all the chunked arrays simultaneously
# --> 542 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     543     *lazy_data.values(), **kwargs
#     544 )
#     546 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     547     self.variables[k].data = data
#
# File r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\namedarray\daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\dask\base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\xarray\core\parallel.py:360, in _wrapper()
#     358 missing_dimensions = set(expected["shapes"]) - set(result.sizes)
#     359 if missing_dimensions:
# --> 360     raise ValueError(
#     361         f"Dimensions {missing_dimensions} missing on returned object."
#     362     )
#     364 # check that index lengths and values are as expected
#     365 for name, index in result._indexes.items():
#
# ValueError: Dimensions {'X', 'Y'} missing on returned object.
