# %%
# 1. Write your custom function here!

# For this demo, we do a basic NDVI calculation, inputting and returning a pandas DataFrame.
# Note that the function must input and return a pandas DataFrame. This is a requirement.
def compute_ndvi(df):
    # Perform your calculations
    df['ndvi'] = (df['SR_B5'] - df['SR_B4']) / (df['SR_B5'] + df['SR_B4'])
    return df[['X', 'Y', 'ndvi']]

def compute_ndvi(df):
    # Perform your calculations
    df['ndvi'] = (df['band_2'] - df['band_1']) / (df['band_2'] + df['band_1'])
    return df[['time', 'X', 'Y', 'ndvi']]

# %%
raster_path = r"R:\SCRATCH\adrianom\landsat_us_test\earthengine-lcs-data\mosaic.tif"

# %%
# 5. Preview the dataset and the results before doing a full run!
# This allows users to inspect the structure and content of the data to ensure it behaves as expected prior to running a full computation.
# 6. Do the full computation here!
# Click on the link to the Dask dashboard to view the computation in real time!
from robustraster import run
import pandas as pd

df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
df_list = ["X", "Y", "ndvi"]

chunks = {"time": 48, "X": 2048, "Y": 1024}
run(
    dataset=raster_path,
    source="local",
    dataset_kwargs={
    #'geometry': Plumas_Boundaries,
    'crs': 'EPSG:3310',
    'scale': 30,
    'output_template': df_list,
    'chunks': chunks
    },
    user_function_params={
        "user_function": compute_ndvi,
        "user_function_args": (),
        "user_function_kwargs": {},
        "chunks": chunks,
        "output_template": df_list,
        "max_iterations": None
    },
    preview_dataset=True

)

# %%
# 6. Do the full computation here!
# Click on the link to the Dask dashboard to view the computation in real time!
from robustraster import run
import pandas as pd

df = pd.DataFrame(columns=["X", "Y", "SR_B4", "SR_B5", "ndvi"])
df_list = ["ndvi"]

chunks = {"time": 48, "X": 4096, "Y": 4096}
run(
    dataset=raster_path,
    source="local",
    dataset_kwargs={
    #'geometry': Plumas_Boundaries,
    'crs': 'EPSG:3310',
    'scale': 30,
    'output_template': df_list,
    'chunks': chunks
},
    user_function_params={
        "user_function": compute_ndvi,
        "user_function_args": (),
        "user_function_kwargs": {},
        "chunks": chunks,
        "output_template": df_list,
        "max_iterations": None
    },
    export_kwargs={
        "mode": "raster",
        "file_format": "GTiff",
        "output_folder": "tiles33",
        "vrt": True,
        "report": True}, 
        #"export_to_gcs": True,
        #"gcs_credentials": r"R:\SCRATCH\adrianom\credentials\cloud_storage\robust-raster-b9a2bc301bc9.json",
        #"gcs_bucket": "raster-bucket-test25678"},
    dask_mode="custom",
    dask_kwargs={
        "n_workers": 8,
        "threads_per_worker": 1,
        "memory_limit": "30GB"
    }
)
# Out:
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\google\cloud\storage\_http.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Dask dashboard is available at: http://127.0.0.1:8787/status
# [robustraster] Dask cluster started: <Client: 'tcp://127.0.0.1:57704' processes=8 threads=8, memory=223.52 GiB>
# [robustraster] Running user function...
# TEMPLATE!!!
#
# <xarray.Dataset> Size: 119GB
# Dimensions:      (time: 1, Y: 96570, X: 153810)
# Coordinates:
#   * time         (time) int32 4B 0
#   * X            (X) float64 1MB -2.356e+06 -2.356e+06 ... 2.258e+06 2.258e+06
#   * Y            (Y) float64 773kB 3.166e+06 3.166e+06 ... 2.687e+05 2.687e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
# Attributes:
#     crs:      EPSG:5070
# DATASET
# <xarray.Dataset> Size: 238GB
# Dimensions:      (time: 1, Y: 96570, X: 153810)
# Coordinates:
#   * time         (time) int32 4B 0
#   * X            (X) float64 1MB -2.356e+06 -2.356e+06 ... 2.258e+06 2.258e+06
#   * Y            (Y) float64 773kB 3.166e+06 3.166e+06 ... 2.687e+05 2.687e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     band_1       (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
#     band_2       (time, Y, X) float64 119GB dask.array<chunksize=(1, 4096, 4096), meta=np.ndarray>
# Attributes:
#     crs:      EPSG:5070
# Exported: tiles33\chunk_-2063291733152109452_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -6.358e+05 -6.358e+05 ... -5.13e+05 -5.13e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1938 0.1891 ... 0.2187 0.2045
# Exported: tiles33\chunk_5576891811291171207_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 4.701e+05 4.701e+05 ... 5.929e+05 5.93e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7137 0.7204 ... 0.7976 0.8173
# Exported: tiles33\chunk_-2613162816735249652_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# Exported: tiles33\chunk_3302569586003441646_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -7.587e+05 -7.587e+05 ... -6.358e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1844 0.1948 ... 0.6874 0.6843
# Exported: tiles33\chunk_-3118750728093106218_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.015e+05 1.015e+05 ... 2.243e+05 2.243e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6126 0.832 ... -0.02564 -0.0259
# Exported: tiles33\chunk_8237680884756304939_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -8.816e+05 -8.815e+05 ... -7.587e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1584 0.1601 ... 0.009798 0.03003
# Exported: tiles33\chunk_6082479722649027773_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -3.9e+05 -3.9e+05 ... -2.672e+05 -2.672e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.05543 0.06984 ... -0.08482
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -2.356e+06 -2.356e+06 ... -2.233e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB nan nan nan ... -3.699 0.7154 0.9626
# Exported: tiles33\chunk_-4724080806617243184_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 7.159e+05 7.159e+05 ... 8.387e+05 8.387e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7178 0.7133 ... 0.6195 0.6291
# Exported: tiles33\chunk_5027020727708031007_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 3.472e+05 3.473e+05 ... 4.701e+05 4.701e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1428 0.1676 ... 0.2912 -0.007181
# Exported: tiles33\chunk_91909428955167714_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.127e+06 -1.127e+06 ... -1.004e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3184 0.3217 ... -0.04957 -0.04279
# Exported: tiles33\chunk_-7548274115488112945_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_4477149644124890807_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -2.233e+06 -2.233e+06 ... -2.11e+06 -2.11e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -11.88 0.5978 ... 0.8296 0.8183
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 2.244e+05 2.244e+05 ... 3.472e+05 3.472e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6343 0.6018 ... 0.5777 0.7745
# Exported: tiles33\chunk_2871819565600753841_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 8.388e+05 8.388e+05 ... 9.616e+05 9.616e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6606 0.6839 ... 0.7866 1.808
# Exported: tiles33\chunk_-1513420649568969252_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-6998403031904972745_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -5.129e+05 -5.129e+05 ... -3.901e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1032 0.08406 ... 0.1587 0.1672
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -2.11e+06 -2.11e+06 ... -1.988e+06 -1.988e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1755 0.3536 ... 0.9208 0.9194
# Exported: tiles33\chunk_7687809801173164739_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.004e+06 -1.004e+06 ... -8.816e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2581 0.229 ... -0.072 -0.07824
# Exported: tiles33\chunk_-5273951890200383384_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 5.93e+05 5.93e+05 ... 7.158e+05 7.158e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.4596 0.504 ... 0.8146 0.7846
# Exported: tiles33\chunk_6632350806232167973_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -2.672e+05 -2.671e+05 ... -1.443e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8207 0.8249 ... -0.08021 -0.09508
# Exported: tiles33\chunk_7182221889815308173_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.443e+05 -1.443e+05 ... -2.144e+04
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5466 0.5317 ... 0.005236 0.002296
# Exported: tiles33\chunk_-3668621811676246418_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -2.14e+04 -2.138e+04 ... 1.014e+05 1.014e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1556 0.3408 1.902 ... 0.7819 0.814
# Exported: tiles33\chunk_7820048032168262169_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 9.616e+05 9.617e+05 ... 1.084e+06 1.084e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8763 0.8994 ... 0.6923 0.7057
# Exported: tiles33\chunk_6214717953644125203_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-1931053502157012022_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.576e+06 1.576e+06 ... 1.699e+06 1.699e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.04257 -0.04257 ... 0.7698 0.7698
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.33e+06 1.33e+06 ... 1.453e+06 1.453e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7696 0.7525 ... 0.6752 0.8615
# Exported: tiles33\chunk_4609387875119988237_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 74MB
# Dimensions:      (time: 1, Y: 4096, X: 2258)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 18kB 2.19e+06 2.19e+06 ... 2.258e+06 2.258e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 74MB 1.228 0.9841 1.419 ... 0.5658 1.369
# Exported: tiles33\chunk_6764589037227265403_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.699e+06 1.699e+06 ... 1.822e+06 1.822e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.683 0.683 0.7201 ... 1.398 12.69
# Exported: tiles33\chunk_5664846870060985003_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.453e+06 1.453e+06 ... 1.576e+06 1.576e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 4.676 -1.918 ... 0.8434 0.8271
# Exported: tiles33\chunk_-2986512497098008788_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 2.068e+06 2.068e+06 ... 2.19e+06 2.19e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7052 0.648 ... 0.6853 0.8509
# Exported: tiles33\chunk_-9153604194012249911_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.619e+06 -1.619e+06 ... -1.496e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5959 0.5016 ... 0.7319 0.7743
# Exported: tiles33\chunk_-8603733110429109711_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_1147368423896164480_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.496e+06 -1.496e+06 ... -1.373e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2249 0.3274 ... 0.6527 0.6684
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.865e+06 -1.865e+06 ... -1.742e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7478 0.8363 ... 0.5296 0.6431
# Exported: tiles33\chunk_597497340313024280_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.987e+06 -1.987e+06 ... -1.865e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 15.12 -25.38 30.46 ... 0.1768 0.1738
# Exported: tiles33\chunk_-2480924585740152222_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.207e+06 1.207e+06 ... 1.33e+06 1.33e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5617 0.5452 ... 0.777 0.7721
# Exported: tiles33\chunk_-1007832738211112686_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.373e+06 -1.373e+06 ... -1.25e+06 -1.25e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -3.104 3.918 ... -0.03279 -0.03775
# Exported: tiles33\chunk_1697239507479304680_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.742e+06 -1.742e+06 ... -1.619e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.348 0.3578 ... 0.2618 0.2144
# Exported: tiles33\chunk_-4086254664264289188_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.822e+06 1.822e+06 ... 1.945e+06 1.945e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3546 0.372 ... 0.03637 0.01205
# Exported: tiles33\chunk_8369919115751402369_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.085e+06 1.085e+06 ... 1.207e+06 1.207e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6292 0.6373 ... -0.033 -0.0339
# Exported: tiles33\chunk_1174544763387751162_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -2.356e+06 -2.356e+06 ... -2.233e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB nan nan nan ... -0.5825 -0.5512
# Exported: tiles33\chunk_-2036115393660522770_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.127e+06 -1.127e+06 ... -1.004e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1624 0.1602 ... -0.0111 -0.03091
# Exported: tiles33\chunk_-3536383580681148988_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.945e+06 1.945e+06 ... 2.067e+06 2.068e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8578 0.8061 ... 0.5403 0.9404
# Exported: tiles33\chunk_-936373226494242370_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -8.816e+05 -8.815e+05 ... -7.587e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.07544 -0.07105 ... -0.06561
# Exported: tiles33\chunk_5604068150782757889_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -2.14e+04 -2.138e+04 ... 1.014e+05 1.014e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.001637 -0.007434 ... -0.06048
# Exported: tiles33\chunk_-1486244310077382570_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.004e+06 -1.004e+06 ... -8.816e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.04325 -0.04307 ... 0.3519 0.3192
# Exported: tiles33\chunk_-457961654627972486_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.25e+06 -1.25e+06 ... -1.127e+06 -1.127e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2409 0.2389 0.253 ... 0.17 0.1653
# Exported: tiles33\chunk_1724415846970891362_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -2.233e+06 -2.233e+06 ... -2.11e+06 -2.11e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7298 1.084 ... 0.8151 0.8032
# Exported: tiles33\chunk_7209398229306894855_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -6.358e+05 -6.358e+05 ... -5.13e+05 -5.13e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6759 0.6833 ... 0.4624 0.4568
# Exported: tiles33\chunk_-2541703305018379336_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -2.672e+05 -2.671e+05 ... -1.443e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.09359 -0.09418 ... 0.2489 0.359
# Exported: tiles33\chunk_-5752363462066653268_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 9.616e+05 9.617e+05 ... 1.084e+06 1.084e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1316 0.1316 ... 0.4893 0.4893
# Exported: tiles33\chunk_7759269312890035055_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -5.129e+05 -5.129e+05 ... -3.901e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3009 0.2823 ... 0.005745 0.02044
# Exported: tiles33\chunk_5054197067199617689_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.443e+05 -1.443e+05 ... -2.144e+04
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.1039 -0.07661 ... 0.5882 0.5753
# Exported: tiles33\chunk_-4147033383542516302_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 3.472e+05 3.473e+05 ... 4.701e+05 4.701e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6405 0.6982 ... -0.01104 -0.03879
# Exported: tiles33\chunk_3998738072258620923_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 5.93e+05 5.93e+05 ... 7.158e+05 7.158e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8075 0.8331 ... 0.8443 0.8428
# Exported: tiles33\chunk_-2409465074023281906_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.699e+06 1.699e+06 ... 1.822e+06 1.822e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7521 0.7449 ... 0.8676 0.8498
# Exported: tiles33\chunk_2274286930554031562_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -2.11e+06 -2.11e+06 ... -1.988e+06 -1.988e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8314 0.847 ... 0.8342 0.8094
# Exported: tiles33\chunk_6659527145723754655_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -7.587e+05 -7.587e+05 ... -6.358e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.13 0.204 0.3202 ... 0.2011 0.1835
# Exported: tiles33\chunk_6241894293135711885_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.085e+06 1.085e+06 ... 1.207e+06 1.207e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6702 0.6753 ... 0.7915 0.8442
# Exported: tiles33\chunk_-3091574388601519536_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_3448866988675480723_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -3.9e+05 -3.9e+05 ... -2.672e+05 -2.672e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1546 0.1583 ... 0.2151 0.2117
# Exported: tiles33\chunk_-4564666236130559072_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 74MB
# Dimensions:      (time: 1, Y: 4096, X: 2258)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 18kB 2.19e+06 2.19e+06 ... 2.258e+06 2.258e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 74MB 0.8279 0.8637 ... 0.7923 0.7823
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 4.701e+05 4.701e+05 ... 5.929e+05 5.93e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -1.372 0.6511 ... 1.811 1.668
# Exported: tiles33\chunk_-2959336157606422106_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.576e+06 1.576e+06 ... 1.699e+06 1.699e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8065 0.8065 ... 1.002 0.8342
# Exported: tiles33\chunk_6153939234365898089_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.015e+05 1.015e+05 ... 2.243e+05 2.243e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6386 0.9187 ... -0.04161 -0.0417
# Exported: tiles33\chunk_-4696904467125656502_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-430785315136385804_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 2.244e+05 2.244e+05 ... 3.472e+05 3.472e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.02989 -0.03702 ... -0.01437
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.742e+06 -1.742e+06 ... -1.619e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5029 0.4615 ... 0.1724 0.1693
# Exported: tiles33\chunk_7341636460301992285_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.33e+06 1.33e+06 ... 1.453e+06 1.453e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7785 0.7711 ... 0.6253 0.8348
# Exported: tiles33\chunk_4548609155841761123_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 7.159e+05 7.159e+05 ... 8.387e+05 8.387e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7932 0.7504 ... 0.5835 0.6156
# Exported: tiles33\chunk_5186435298194715119_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.822e+06 1.822e+06 ... 1.945e+06 1.945e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -3.86 1.817 ... 0.08755 0.1266
# 2025-12-05 15:50:52,738 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:57740 (pid=74968) exceeded 95% memory budget. Restarting...
# 2025-12-05 15:50:52,764 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:57740' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 0, 19), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 1, 19), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 0, 6), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 0, 12), ("band_2-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16-'getitem-13296cb9a1eb6ca15c2ba4a41874fc0c'", 0, 1, 35), ('user_function_export_wrapper-ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 1, 30), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 0, 28), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 1, 15), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 0, 8), ('ndvi-_user_function_export_wrapper-9ae969157cbf3e5d4c9cb33b15569d16', 0, 0, 21)} (stimulus_id='handle-worker-cleanup-1764978652.7677853')
# Exported: tiles33\chunk_-8576556770937523029_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.987e+06 -1.987e+06 ... -1.865e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.9109 0.9054 ... 0.6567 0.6738
# 2025-12-05 15:50:58,641 - distributed.nanny - WARNING - Restarting worker
# Exported: tiles33\chunk_8264857224247891621_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.373e+06 -1.373e+06 ... -1.25e+06 -1.25e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6547 0.6768 ... 0.2829 0.3141
# Exported: tiles33\chunk_-6302234545649793468_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 8.388e+05 8.388e+05 ... 9.616e+05 9.616e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6456 0.6209 ... 0.9095 0.8342
# Exported: tiles33\chunk_6791765376718852085_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.207e+06 1.207e+06 ... 1.33e+06 1.33e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6796 0.6925 ... 0.817 0.8181
# Exported: tiles33\chunk_367680479344916271_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -1.004e+06 -1.004e+06 ... -8.816e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7033 0.7365 ... -0.01829 -0.01321
# Exported: tiles33\chunk_-5114537319713699272_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 2.068e+06 2.068e+06 ... 2.19e+06 2.19e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1164 0.01744 ... 0.9837 0.8698
# Exported: tiles33\chunk_3578340636393190203_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -2.233e+06 -2.233e+06 ... -2.11e+06 -2.11e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.4618 0.5105 ... 0.311 0.4207
# Exported: tiles33\chunk_6358250773038776330_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -2.672e+05 -2.671e+05 ... -1.443e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.01782 -0.01716 ... 0.2872 0.2597
# Exported: tiles33\chunk_8513451935146053496_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -7.587e+05 -7.587e+05 ... -6.358e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3063 0.3075 ... 0.1542 0.1512
# Exported: tiles33\chunk_-3668621811676246418_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -2.14e+04 -2.138e+04 ... 1.014e+05 1.014e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1556 0.3408 1.902 ... 0.7819 0.814
# Exported: tiles33\chunk_-182190604238223929_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -1.127e+06 -1.127e+06 ... -1.004e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1726 0.1698 ... 0.2096 0.261
# Exported: tiles33\chunk_-1237649599179220695_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-8026685687354382829_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -3.9e+05 -3.9e+05 ... -2.672e+05 -2.672e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.002702 0.01475 ... 0.2815 0.3148
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.865e+06 -1.865e+06 ... -1.742e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1743 0.1899 ... 0.08835 0.06079
# Exported: tiles33\chunk_-1787520682762360895_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -5.129e+05 -5.129e+05 ... -3.901e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2372 0.2469 ... 0.222 0.2163
# Exported: tiles33\chunk_5736306381777855319_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_3028469552810050003_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_8814728307831031821_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.945e+06 1.945e+06 ... 2.067e+06 2.068e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.03548 0.1372 ... 0.2902 0.2596
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -2.356e+06 -2.356e+06 ... -2.233e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2011 0.358 0.2016 ... 0.4092 0.371
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.25e+06 -1.25e+06 ... -1.127e+06 -1.127e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.04161 -0.04175 ... 0.1597 0.1681
# Exported: tiles33\chunk_4477149644124890807_time_0.tif with bands ['ndvi']
# FINAL DATASET!
# Exported: tiles33\chunk_-3509207241189562306_time_0.tif with bands ['ndvi']
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 2.244e+05 2.244e+05 ... 3.472e+05 3.472e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6343 0.6018 ... 0.5777 0.7745
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB 1.453e+06 1.453e+06 ... 1.576e+06 1.576e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 1.141 2.277 2.898 ... 1.042 0.3083
# Exported: tiles33\chunk_8369919115751402369_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB 1.085e+06 1.085e+06 ... 1.207e+06 1.207e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6292 0.6373 ... -0.033 -0.0339
# Exported: tiles33\chunk_7963580851562913296_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -8.816e+05 -8.815e+05 ... -7.587e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3879 0.1048 ... 0.5733 0.6168
# Exported: tiles33\chunk_119085768446754396_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.043e+06 3.043e+06 ... 2.92e+06 2.92e+06
#   * X            (X) float64 33kB -1.619e+06 -1.619e+06 ... -1.496e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2567 0.3673 ... 0.871 0.8664
# Exported: tiles33\chunk_8237680884756304939_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -8.816e+05 -8.815e+05 ... -7.587e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1584 0.1601 ... 0.009798 0.03003
# Exported: tiles33\chunk_-9153604194012249911_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 3.166e+06 3.166e+06 ... 3.043e+06 3.043e+06
#   * X            (X) float64 33kB -1.619e+06 -1.619e+06 ... -1.496e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5959 0.5016 ... 0.7319 0.7743
# Exported: tiles33\chunk_1005506621697870267_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB 1.015e+05 1.015e+05 ... 2.243e+05 2.243e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6741 0.6697 ... 0.2479 0.2453
# Exported: tiles33\chunk_6908121856621916530_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
#   * X            (X) float64 33kB -1.443e+05 -1.443e+05 ... -2.144e+04
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3629 0.3639 ... 0.4453 0.475
# Exported: tiles33\chunk_-7272503065098364388_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-1007832738211112686_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 1.937e+06 1.937e+06 ... 1.814e+06 1.814e+06
# ...
# Exported: tiles33\chunk_7386533428488186414_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -5.129e+05 -5.129e+05 ... -3.901e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2661 0.2527 ... -0.01974 -0.01695
# Exported: tiles33\chunk_8068642743066424044_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.576e+06 1.576e+06 ... 1.699e+06 1.699e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7882 0.8294 ... 0.6007 0.4639
# Exported: tiles33\chunk_-1309109110896091011_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_-759238027312950811_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -8.816e+05 -8.815e+05 ... -7.587e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1123 0.1315 ... 0.2627 0.2762
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -7.587e+05 -7.587e+05 ... -6.358e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2269 0.2229 ... 0.2974 0.2963
# Exported: tiles33\chunk_9124101738007420810_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 8.388e+05 8.388e+05 ... 9.616e+05 9.616e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.6608 0.5003 ... 0.4072 0.3295
# Exported: tiles33\chunk_2451422129735323121_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.987e+06 -1.987e+06 ... -1.865e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1193 0.1227 ... 0.1131 0.0945
# Exported: tiles33\chunk_3001293213318463321_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.865e+06 -1.865e+06 ... -1.742e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1289 0.1469 ... 0.1081 -0.03629
# Exported: tiles33\chunk_-1176870879900993581_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.085e+06 1.085e+06 ... 1.207e+06 1.207e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.192 0.2214 ... 0.5273 0.4936
# Exported: tiles33\chunk_8574230654424280610_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 7.159e+05 7.159e+05 ... 8.387e+05 8.387e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2068 0.3484 0.56 ... 0.4915 0.5225
# Exported: tiles33\chunk_-8267183340761134040_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.015e+05 1.015e+05 ... 2.243e+05 2.243e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2264 0.2374 ... 0.1413 0.1694
# Exported: tiles33\chunk_-209366943729810611_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -6.358e+05 -6.358e+05 ... -5.13e+05 -5.13e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2586 0.2371 ... 0.2581 0.2562
# Exported: tiles33\chunk_6968900575900143644_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.33e+06 1.33e+06 ... 1.453e+06 1.453e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.8639 0.8479 ... 0.8065 0.8516
# Exported: tiles33\chunk_-2364568105837087777_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.443e+05 -1.443e+05 ... -2.144e+04
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3391 0.4291 ... 0.04356 0.06388
# Exported: tiles33\chunk_-7717312257177993840_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 2.244e+05 2.244e+05 ... 3.472e+05 3.472e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5011 0.5559 ... 0.4994 0.3934
# Exported: tiles33\chunk_-2782200958425130547_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.699e+06 1.699e+06 ... 1.822e+06 1.822e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.4103 0.3842 ... -4.341 -2.152
# Exported: tiles33\chunk_-626999796317853381_time_0.tif with bands ['ndvi']
# Exported: tiles33\chunk_6463312664542287078_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 74MB
# Dimensions:      (time: 1, Y: 4096, X: 2258)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 18kB 2.19e+06 2.19e+06 ... 2.258e+06 2.258e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 74MB nan nan nan nan ... nan nan nan nan
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.207e+06 1.207e+06 ... 1.33e+06 1.33e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.4612 0.4612 ... 0.5013 0.4902
# Exported: tiles33\chunk_-7167441173594853640_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 3.472e+05 3.473e+05 ... 4.701e+05 4.701e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2447 0.1922 ... 0.3197 0.2989
# Exported: tiles33\chunk_-2232329874841990347_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.822e+06 1.822e+06 ... 1.945e+06 1.945e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.7594 0.7517 0.743 ... 1.391 0.3432
# Exported: tiles33\chunk_-8772771252118990606_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 9.616e+05 9.617e+05 ... 1.084e+06 1.084e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2027 0.2014 ... 0.7757 0.7871
# Exported: tiles33\chunk_7518771659483283844_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.453e+06 1.453e+06 ... 1.576e+06 1.576e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.5009 0.4932 ... 0.5748 0.5968
# Exported: tiles33\chunk_5913441580959146878_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 2.068e+06 2.068e+06 ... 2.19e+06 2.19e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB nan nan nan nan ... nan nan nan nan
# Exported: tiles33\chunk_8486275595654466814_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -2.672e+05 -2.671e+05 ... -1.443e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB -0.02907 -0.02532 ... 0.3489 0.3836
# Exported: tiles33\chunk_296220967628045955_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.496e+06 -1.496e+06 ... -1.373e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.09779 0.09805 ... 0.1056 0.1853
# Exported: tiles33\chunk_428459198623143385_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 4.701e+05 4.701e+05 ... 5.929e+05 5.93e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1968 0.1569 ... 0.4636 0.5713
# Exported: tiles33\chunk_7936404512071326614_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -3.9e+05 -3.9e+05 ... -2.672e+05 -2.672e+05
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.2498 0.2566 ... -0.02041 -0.02046
# Exported: tiles33\chunk_-1682458791258850147_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB 1.945e+06 1.945e+06 ... 2.067e+06 2.068e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.22 -0.016 0.1333 ... nan nan nan
# Exported: tiles33\chunk_-7849550488173091270_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.742e+06 -1.742e+06 ... -1.619e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.136 0.1277 ... 0.1995 0.2054
# Exported: tiles33\chunk_1901551046152182921_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -2.11e+06 -2.11e+06 ... -1.988e+06 -1.988e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.896 0.8828 ... -2.503 0.1334
# Exported: tiles33\chunk_-7299679404589951070_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.619e+06 -1.619e+06 ... -1.496e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.1617 0.2018 ... 0.1876 0.1629
# Exported: tiles33\chunk_1395963134794326355_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.25e+06 -1.25e+06 ... -1.127e+06 -1.127e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.07533 0.03111 ... 0.1932 0.1669
# Exported: tiles33\chunk_846092051211186155_time_0.tif with bands ['ndvi']
# FINAL DATASET!
#
#
# <xarray.Dataset> Size: 134MB
# Dimensions:      (time: 1, Y: 4096, X: 4096)
# Coordinates:
#   * time         (time) int32 4B 0
#   * Y            (Y) float64 33kB 2.06e+06 2.06e+06 ... 1.937e+06 1.937e+06
#   * X            (X) float64 33kB -1.373e+06 -1.373e+06 ... -1.25e+06 -1.25e+06
#     spatial_ref  int32 4B 0
# Data variables:
#     ndvi         (time, Y, X) float64 134MB 0.3396 0.3408 ... 0.1435 0.07229
# r:\Users\adrianom.UNR\.conda\envs\rreditmode\lib\site-packages\osgeo\gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# VRT file created successfully: tiles33\time_0.vrt
# [robustraster] Dask client closed.
# [robustraster] Dask cluster shut down.
