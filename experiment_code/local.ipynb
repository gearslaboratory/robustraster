# %%
import xarray as xr
import rioxarray
import glob

# %%
help(xr.open_mfdataset)

# %%
file_paths = glob.glob(r"R:\Users\adrianom.UNR\Downloads\going_down_on_me\*.tif")
#ds = xr.open_dataset(r"R:\Users\adrianom.UNR\Downloads\going_down_on_me\LC08_043033_20190410.tif", engine="rasterio", chunks="auto")
ds = xr.open_mfdataset(file_paths, engine="rasterio", chunks='auto', combine="nested", concat_dim="time", band_as_variable=True)

# %%
sa_file_paths = glob.glob(r"R:\SCRATCH\adrianom\Classes\Fall 2023\GEOG 616\fproject\data\*.tif")
ds2 = xr.open_mfdataset(sa_file_paths, engine="rasterio", chunks='auto', combine="nested", concat_dim="time", band_as_variable=True)

# %%
print(ds2.crs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 print(ds2.crs)
#
# File r:\Users\adrianom.UNR\AppData\Local\anaconda3\envs\grad\Lib\site-packages\xarray\core\common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'crs'
